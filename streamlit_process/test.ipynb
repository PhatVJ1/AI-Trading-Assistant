# %%
import trading
import plot
# Out:
# 2023-11-08 10:42:57.813
# ...
#   command:
#
#     streamlit run c:\Users\Nguyen Phat\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# [*********************100%***********************]  1 of 1 completed
